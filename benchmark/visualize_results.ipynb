# %%
import benchmark_client
benchllm=benchmark_client.BenchLLMClient('##','##')
# results from llm_on_edge/main.py --stages benchmark are saved alongside main repository:
# ./llm_on_edge
# ./out/smollm2/
# ./out/olmo2/
result_df=benchllm.compare_results('../../out/smollm2/benchmark_results/out/smollm2','../../out/smollm2/benchmark_results/out/smollm2/original/smollm2_q16.gguf.json')
# p value is calculated for accuracy with McNemar's test p-value relative to base model
result_df
# Out:
# 2026-04-30 13:47:20,726 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 13:47:20,777 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/hotpotqa/hotpot_qa/1908d6afbbead072334abe2965f91bd2709910ab/README.md "HTTP/1.1 200 OK"
# 2026-04-30 13:47:20,963 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/1908d6afbbead072334abe2965f91bd2709910ab/hotpot_qa.py "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:18,884 - INFO - HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/hotpotqa/hotpot_qa/hotpotqa/hotpot_qa.py "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:19,073 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/1908d6afbbead072334abe2965f91bd2709910ab/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:19,465 - INFO - HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=hotpotqa/hotpot_qa "HTTP/1.1 200 OK"
# 2026-04-30 13:47:19,657 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/1908d6afbbead072334abe2965f91bd2709910ab/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:19,676 - INFO - 25 json_files: ['../../out/smollm2/benchmark_results/out/smollm2/original/smollm2_q16.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.5_gptq_4.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_gptq_8.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.2_gptq_4.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.5_gptq_8.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.5_gptq_4.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_gptq_4.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.5_gptq_8.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.2_gptq_8.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.2_gptq_4.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.2_gptq_8.json', '../../out/smollm2/benchmark_results/out/smollm2/pruned/unstructured/wanda/0.2/smollm2_unstructured_wanda_0.2_q16.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/pruned/unstructured/wanda/0.5/smollm2_unstructured_wanda_0.5_q16.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/pruned/unstructured/sparsegpt/0.2/smollm2_unstructured_sparsegpt_0.2_q16.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/pruned/unstructured/sparsegpt/0.5/smollm2_unstructured_sparsegpt_0.5_q16.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.5_llama.cpp_4/smollm2_unstructured_sparsegpt_0.5_IQ4_XS.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.2_llama.cpp_8/smollm2_unstructured_sparsegpt_0.2_Q8_0.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.2_llama.cpp_4/smollm2_unstructured_wanda_0.2_IQ4_XS.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.5_llama.cpp_4/smollm2_unstructured_wanda_0.5_IQ4_XS.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.5_llama.cpp_8/smollm2_unstructured_sparsegpt_0.5_Q8_0.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_llama.cpp_8/smollm2_Q8_0.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_llama.cpp_4/smollm2_IQ4_XS.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_sparsegpt_0.2_llama.cpp_4/smollm2_unstructured_sparsegpt_0.2_IQ4_XS.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.2_llama.cpp_8/smollm2_unstructured_wanda_0.2_Q8_0.gguf.json', '../../out/smollm2/benchmark_results/out/smollm2/quantized/smollm2_unstructured_wanda_0.5_llama.cpp_8/smollm2_unstructured_wanda_0.5_Q8_0.gguf.json']
#                                                method accuracy           ppl  \
# 0                               smollm2_q16.gguf.json     0.30    9.68+-0.50
# 1      smollm2_unstructured_sparsegpt_0.5_gptq_4.json     0.23  38.92+-27.06
# 2                                 smollm2_gptq_8.json     0.31  22.16+-17.15
# 3          smollm2_unstructured_wanda_0.2_gptq_4.json     0.32  24.11+-16.05
# 4          smollm2_unstructured_wanda_0.5_gptq_8.json     0.21  32.94+-21.85
# 5          smollm2_unstructured_wanda_0.5_gptq_4.json     0.26  38.85+-25.40
# 6                                 smollm2_gptq_4.json     0.29  23.98+-15.82
# 7      smollm2_unstructured_sparsegpt_0.5_gptq_8.json     0.21  32.63+-21.32
# 8      smollm2_unstructured_sparsegpt_0.2_gptq_8.json     0.32  21.57+-14.60
# 9      smollm2_unstructured_sparsegpt_0.2_gptq_4.json     0.30  24.51+-16.43
# 10         smollm2_unstructured_wanda_0.2_gptq_8.json     0.32  21.26+-14.34
# 11       smollm2_unstructured_wanda_0.2_q16.gguf.json     0.32    9.85+-0.52
# 12       smollm2_unstructured_wanda_0.5_q16.gguf.json     0.24   14.97+-0.88
# 13   smollm2_unstructured_sparsegpt_0.2_q16.gguf.json     0.30    9.94+-0.52
# 14   smollm2_unstructured_sparsegpt_0.5_q16.gguf.json     0.23   14.69+-0.85
# 15  smollm2_unstructured_sparsegpt_0.5_IQ4_XS.gguf...     0.26   16.35+-0.99
# 16  smollm2_unstructured_sparsegpt_0.2_Q8_0.gguf.json     0.29    9.95+-0.52
# 17    smollm2_unstructured_wanda_0.2_IQ4_XS.gguf.json     0.29   10.64+-0.57
# 18    smollm2_unstructured_wanda_0.5_IQ4_XS.gguf.json     0.26   16.95+-1.02
# 19  smollm2_unstructured_sparsegpt_0.5_Q8_0.gguf.json     0.24   14.76+-0.85
# 20                             smollm2_Q8_0.gguf.json     0.30    9.70+-0.50
# 21                           smollm2_IQ4_XS.gguf.json     0.28   10.54+-0.55
# 22  smollm2_unstructured_sparsegpt_0.2_IQ4_XS.gguf...     0.29   10.72+-0.57
# 23      smollm2_unstructured_wanda_0.2_Q8_0.gguf.json     0.32    9.87+-0.52
# 24      smollm2_unstructured_wanda_0.5_Q8_0.gguf.json     0.26   15.04+-0.87
#
#          prefill        decode correct->correct correct->incorrect  \
# 0    37.66+-2.20    9.29+-0.68             0.30               0.00
# 1    46.29+-6.39   24.95+-5.81             0.17               0.12
# 2   56.01+-10.17   19.94+-4.09             0.28               0.01
# 3    34.23+-4.05  34.50+-10.82             0.23               0.07
# 4    53.19+-9.70   18.50+-4.38             0.17               0.12
# 5    43.41+-6.01  27.53+-40.47             0.20               0.10
# 6    44.22+-6.41   29.27+-6.13             0.24               0.06
# 7   53.32+-10.01   18.53+-4.29             0.17               0.12
# 8   50.56+-10.58   18.59+-4.59             0.26               0.04
# 9    34.23+-4.05   20.47+-5.56             0.23               0.07
# 10  55.10+-10.99   18.78+-4.30             0.25               0.05
# 11   36.54+-2.79    9.00+-0.44             0.26               0.04
# 12   36.53+-2.25    8.92+-0.28             0.19               0.11
# 13   36.95+-2.23    8.87+-0.26             0.26               0.04
# 14   36.97+-2.28    8.98+-0.34             0.18               0.12
# 15   44.21+-2.97   27.07+-2.20             0.20               0.10
# 16   77.24+-6.97   15.73+-0.57             0.24               0.06
# 17   43.68+-3.26   26.59+-2.05             0.23               0.07
# 18   43.24+-3.29   26.34+-1.70             0.20               0.10
# 19   76.67+-8.44   15.96+-0.65             0.18               0.12
# 20   76.72+-7.53   16.14+-1.14             0.28               0.02
# 21   44.16+-2.89   27.14+-2.09             0.22               0.08
# 22   43.91+-2.80   26.54+-1.75             0.22               0.08
# 23   74.14+-8.96   15.97+-0.74             0.25               0.05
# 24   75.94+-8.55   15.78+-0.54             0.19               0.11
#
#    incorrect->correct incorrect->incorrect mcNemar p value for accuracy  \
# 0                0.00                 0.70                    nan,n=200
# 1                0.06                 0.65                   0.02,n=200
# 2                0.03                 0.68                   0.48,n=200
# 3                0.09                 0.61                   0.47,n=200
# 4                0.04                 0.66                   0.00,n=200
# 5                0.06                 0.65                   0.14,n=200
# 6                0.05                 0.65                   0.67,n=200
# 7                0.04                 0.66                   0.00,n=200
# 8                0.06                 0.65                   0.49,n=200
# 9                0.07                 0.63                   0.85,n=200
# 10               0.07                 0.64                   0.53,n=200
# 11               0.06                 0.64                   0.51,n=200
# 12               0.06                 0.65                   0.06,n=200
# 13               0.04                 0.66                   1.00,n=200
# 14               0.04                 0.66                   0.01,n=200
# 15               0.06                 0.64                   0.12,n=200
# 16               0.04                 0.66                   0.65,n=200
# 17               0.07                 0.64                   0.85,n=200
# 18               0.06                 0.64                   0.12,n=200
# 19               0.06                 0.65                   0.04,n=200
# 20               0.02                 0.68                   1.00,n=200
# 21               0.06                 0.64                   0.45,n=200
# 22               0.07                 0.63                   0.72,n=200
# 23               0.07                 0.64                   0.53,n=200
# 24               0.07                 0.64                   0.13,n=200
#
#       CI (95%)
# 0      nan,nan
# 1    0.01,0.13
# 2   -0.04,0.02
# 3   -0.07,0.03
# 4    0.03,0.14
# 5   -0.01,0.09
# 6   -0.04,0.06
# 7    0.03,0.14
# 8   -0.06,0.03
# 9   -0.06,0.05
# 10  -0.06,0.03
# 11  -0.06,0.03
# 12  -0.00,0.11
# 13  -0.04,0.04
# 14   0.02,0.13
# 15  -0.01,0.10
# 16  -0.03,0.05
# 17  -0.05,0.06
# 18  -0.01,0.10
# 19   0.00,0.12
# 20  -0.03,0.03
# 21  -0.03,0.07
# 22  -0.04,0.06
# 23  -0.06,0.03
# 24  -0.01,0.10

# %%
benchllm.calc_corr(result_df)
# Out:
#                               accuracy       ppl   prefill    decode  \
# accuracy                      1.000000 -0.443594 -0.021415  0.049245
# ppl                          -0.443594  1.000000 -0.171862  0.401321
# prefill                      -0.021415 -0.171862  1.000000 -0.153129
# decode                        0.049245  0.401321 -0.153129  1.000000
# correct->correct              0.875676 -0.480305  0.012676 -0.192581
# correct->incorrect           -0.851039  0.429614 -0.019169  0.192196
# incorrect->correct            0.128393  0.130184 -0.115497  0.505380
# incorrect->incorrect         -0.128247 -0.081881  0.208914 -0.538564
# mcNemar p value for accuracy       NaN       NaN       NaN       NaN
# CI (95%)                           NaN       NaN       NaN       NaN
#
#                               correct->correct  correct->incorrect  \
# accuracy                              0.875676           -0.851039
# ppl                                  -0.480305            0.429614
# prefill                               0.012676           -0.019169
# decode                               -0.192581            0.192196
# correct->correct                      1.000000           -0.995365
# correct->incorrect                   -0.995365            1.000000
# incorrect->correct                   -0.355314            0.391913
# incorrect->incorrect                  0.348614           -0.388824
# mcNemar p value for accuracy               NaN                 NaN
# CI (95%)                                   NaN                 NaN
#
#                               incorrect->correct  incorrect->incorrect  \
# accuracy                                0.128393             -0.128247
# ppl                                     0.130184             -0.081881
# prefill                                -0.115497              0.208914
# decode                                  0.505380             -0.538564
# correct->correct                       -0.355314              0.348614
# correct->incorrect                      0.391913             -0.388824
# incorrect->correct                      1.000000             -0.965381
# incorrect->incorrect                   -0.965381              1.000000
# mcNemar p value for accuracy                 NaN                   NaN
# CI (95%)                                     NaN                   NaN
#
#                               mcNemar p value for accuracy  CI (95%)
# accuracy                                               NaN       NaN
# ppl                                                    NaN       NaN
# prefill                                                NaN       NaN
# decode                                                 NaN       NaN
# correct->correct                                       NaN       NaN
# correct->incorrect                                     NaN       NaN
# incorrect->correct                                     NaN       NaN
# incorrect->incorrect                                   NaN       NaN
# mcNemar p value for accuracy                           NaN       NaN
# CI (95%)                                               NaN       NaN

# %%
import benchmark_client
benchllm=benchmark_client.BenchLLMClient('##','##')
result_df=benchllm.compare_results('../../out/olmo2/benchmark_results/out/olmo2','../../out/olmo2/benchmark_results/out/olmo2/original/olmo2_q16.gguf.json')
result_df
# Out:
# 2026-04-30 13:47:20,660 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-04-30 13:47:20,713 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/hotpotqa/hotpot_qa/1908d6afbbead072334abe2965f91bd2709910ab/README.md "HTTP/1.1 200 OK"
# 2026-04-30 13:47:20,899 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/1908d6afbbead072334abe2965f91bd2709910ab/hotpot_qa.py "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:21,057 - INFO - HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/hotpotqa/hotpot_qa/hotpotqa/hotpot_qa.py "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:21,251 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/1908d6afbbead072334abe2965f91bd2709910ab/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:21,444 - INFO - HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=hotpotqa/hotpot_qa "HTTP/1.1 200 OK"
# 2026-04-30 13:47:21,627 - INFO - HTTP Request: HEAD https://huggingface.co/datasets/hotpotqa/hotpot_qa/resolve/1908d6afbbead072334abe2965f91bd2709910ab/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-04-30 13:47:21,644 - INFO - 25 json_files: ['../../out/olmo2/benchmark_results/out/olmo2/original/olmo2_q16.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.5_gptq_4.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.5_gptq_8.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.2_gptq_8.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_gptq_4.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.2_gptq_4.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.2_gptq_4.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.5_gptq_8.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.2_gptq_8.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_gptq_8.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.5_gptq_4.json', '../../out/olmo2/benchmark_results/out/olmo2/pruned/unstructured/wanda/0.2/olmo2_unstructured_wanda_0.2_q16.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/pruned/unstructured/wanda/0.5/olmo2_unstructured_wanda_0.5_q16.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/pruned/unstructured/sparsegpt/0.2/olmo2_unstructured_sparsegpt_0.2_q16.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/pruned/unstructured/sparsegpt/0.5/olmo2_unstructured_sparsegpt_0.5_q16.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.2_llama.cpp_4/olmo2_unstructured_wanda_0.2_IQ4_XS.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_llama.cpp_8/olmo2_Q8_0.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.2_llama.cpp_8/olmo2_unstructured_sparsegpt_0.2_Q8_0.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.5_llama.cpp_8/olmo2_unstructured_wanda_0.5_Q8_0.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.5_llama.cpp_4/olmo2_unstructured_sparsegpt_0.5_IQ4_XS.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.2_llama.cpp_4/olmo2_unstructured_sparsegpt_0.2_IQ4_XS.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.2_llama.cpp_8/olmo2_unstructured_wanda_0.2_Q8_0.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_llama.cpp_4/olmo2_IQ4_XS.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_wanda_0.5_llama.cpp_4/olmo2_unstructured_wanda_0.5_IQ4_XS.gguf.json', '../../out/olmo2/benchmark_results/out/olmo2/quantized/olmo2_unstructured_sparsegpt_0.5_llama.cpp_8/olmo2_unstructured_sparsegpt_0.5_Q8_0.gguf.json']
#                                                method accuracy           ppl  \
# 0                                 olmo2_q16.gguf.json     0.14   13.81+-0.86
# 1        olmo2_unstructured_sparsegpt_0.5_gptq_4.json     0.27  38.57+-23.48
# 2            olmo2_unstructured_wanda_0.5_gptq_8.json     0.24  37.66+-21.73
# 3            olmo2_unstructured_wanda_0.2_gptq_8.json     0.29  30.68+-17.56
# 4                                   olmo2_gptq_4.json     0.28  24.16+-16.74
# 5        olmo2_unstructured_sparsegpt_0.2_gptq_4.json     0.28  33.22+-18.81
# 6            olmo2_unstructured_wanda_0.2_gptq_4.json     0.32  24.11+-16.05
# 7        olmo2_unstructured_sparsegpt_0.5_gptq_8.json     0.24  37.07+-23.09
# 8        olmo2_unstructured_sparsegpt_0.2_gptq_8.json     0.28  31.31+-17.89
# 9                                   olmo2_gptq_8.json     0.14  21.73+-16.54
# 10           olmo2_unstructured_wanda_0.5_gptq_4.json     0.23  39.83+-22.94
# 11         olmo2_unstructured_wanda_0.2_q16.gguf.json     0.31   13.96+-0.85
# 12         olmo2_unstructured_wanda_0.5_q16.gguf.json     0.23   17.63+-1.00
# 13     olmo2_unstructured_sparsegpt_0.2_q16.gguf.json     0.29   21.16+-1.48
# 14     olmo2_unstructured_sparsegpt_0.5_q16.gguf.json     0.27   16.69+-0.95
# 15      olmo2_unstructured_wanda_0.2_IQ4_XS.gguf.json     0.28   14.68+-0.87
# 16                               olmo2_Q8_0.gguf.json     0.14   13.83+-0.86
# 17    olmo2_unstructured_sparsegpt_0.2_Q8_0.gguf.json     0.28   21.18+-1.48
# 18        olmo2_unstructured_wanda_0.5_Q8_0.gguf.json     0.26   17.66+-1.00
# 19  olmo2_unstructured_sparsegpt_0.5_IQ4_XS.gguf.json     0.23   17.31+-0.94
# 20  olmo2_unstructured_sparsegpt_0.2_IQ4_XS.gguf.json     0.28   22.80+-1.58
# 21        olmo2_unstructured_wanda_0.2_Q8_0.gguf.json     0.28   13.97+-0.85
# 22                             olmo2_IQ4_XS.gguf.json     0.16   14.64+-0.88
# 23      olmo2_unstructured_wanda_0.5_IQ4_XS.gguf.json     0.24   18.69+-1.08
# 24    olmo2_unstructured_sparsegpt_0.5_Q8_0.gguf.json     0.28   16.69+-0.95
#
#           prefill        decode correct->correct correct->incorrect  \
# 0     58.64+-4.50   12.78+-1.15             0.14               0.00
# 1     60.89+-6.28  45.24+-10.71             0.09               0.06
# 2    60.85+-10.33   23.48+-8.18             0.06               0.09
# 3     61.85+-9.51   31.27+-7.87             0.09               0.06
# 4     63.12+-8.95   25.85+-3.80             0.08               0.07
# 5     70.82+-6.42  30.54+-11.40             0.10               0.05
# 6     53.27+-7.28  59.14+-12.93             0.09               0.06
# 7    60.85+-10.33   23.41+-8.14             0.07               0.07
# 8    68.35+-13.53   29.15+-5.54             0.09               0.06
# 9    71.48+-16.22   30.39+-6.31             0.04               0.10
# 10    61.11+-8.53  43.25+-10.39             0.06               0.09
# 11    59.46+-4.21   13.91+-2.05             0.10               0.05
# 12    58.61+-4.62   13.71+-2.02             0.07               0.08
# 13    58.68+-4.39   14.18+-2.52             0.10               0.05
# 14    60.81+-3.47   13.70+-1.83             0.08               0.07
# 15    72.77+-5.16   41.84+-6.98             0.08               0.07
# 16  126.95+-12.85   23.25+-3.03             0.06               0.09
# 17  125.54+-13.72   24.91+-4.40             0.09               0.06
# 18  126.43+-13.11   25.22+-4.35             0.07               0.07
# 19    72.56+-4.39   40.48+-5.87             0.07               0.07
# 20    71.91+-4.89   41.40+-6.62             0.09               0.06
# 21  124.48+-12.71   24.38+-4.09             0.09               0.06
# 22    71.44+-4.76   38.36+-5.03             0.05               0.10
# 23    71.21+-4.84   40.80+-6.01             0.07               0.07
# 24  122.38+-13.20   23.55+-2.70             0.09               0.06
#
#    incorrect->correct incorrect->incorrect mcNemar p value for accuracy  \
# 0                0.00                 0.85                    nan,n=200
# 1                0.18                 0.67                   0.00,n=200
# 2                0.18                 0.68                   0.01,n=200
# 3                0.20                 0.65                   0.00,n=200
# 4                0.20                 0.65                   0.00,n=200
# 5                0.18                 0.67                   0.00,n=200
# 6                0.23                 0.62                   0.00,n=200
# 7                0.17                 0.69                   0.01,n=200
# 8                0.20                 0.66                   0.00,n=200
# 9                0.10                 0.76                   1.00,n=200
# 10               0.17                 0.69                   0.02,n=200
# 11               0.21                 0.64                   0.00,n=200
# 12               0.17                 0.69                   0.02,n=200
# 13               0.20                 0.66                   0.00,n=200
# 14               0.19                 0.67                   0.00,n=200
# 15               0.20                 0.65                   0.00,n=200
# 16               0.08                 0.78                   0.73,n=200
# 17               0.19                 0.67                   0.00,n=200
# 18               0.19                 0.67                   0.00,n=200
# 19               0.15                 0.70                   0.01,n=200
# 20               0.18                 0.67                   0.00,n=200
# 21               0.19                 0.67                   0.00,n=200
# 22               0.11                 0.74                   0.64,n=200
# 23               0.17                 0.69                   0.01,n=200
# 24               0.19                 0.67                   0.00,n=200
#
#        CI (95%)
# 0       nan,nan
# 1   -0.19,-0.06
# 2   -0.17,-0.02
# 3   -0.22,-0.07
# 4   -0.21,-0.07
# 5   -0.20,-0.07
# 6   -0.25,-0.10
# 7   -0.16,-0.03
# 8   -0.21,-0.07
# 9    -0.06,0.06
# 10  -0.15,-0.02
# 11  -0.24,-0.09
# 12  -0.15,-0.02
# 13  -0.22,-0.08
# 14  -0.19,-0.06
# 15  -0.21,-0.07
# 16   -0.05,0.07
# 17  -0.20,-0.06
# 18  -0.19,-0.04
# 19  -0.15,-0.02
# 20  -0.20,-0.06
# 21  -0.20,-0.06
# 22   -0.08,0.05
# 23  -0.16,-0.03
# 24  -0.20,-0.06

# %%
benchllm.calc_corr(result_df)
# Out:
#                               accuracy       ppl   prefill    decode  \
# accuracy                      1.000000  0.206638 -0.072735  0.145451
# ppl                           0.206638  1.000000 -0.393572  0.294942
# prefill                      -0.072735 -0.393572  1.000000 -0.150341
# decode                        0.145451  0.294942 -0.150341  1.000000
# correct->correct              0.363193 -0.115072 -0.099512 -0.252218
# correct->incorrect           -0.266076  0.141894  0.098332  0.258147
# incorrect->correct            0.921781  0.274062 -0.048364  0.219953
# incorrect->incorrect         -0.935528 -0.269553  0.090155 -0.260521
# mcNemar p value for accuracy       NaN       NaN       NaN       NaN
# CI (95%)                           NaN       NaN       NaN       NaN
#
#                               correct->correct  correct->incorrect  \
# accuracy                              0.363193           -0.266076
# ppl                                  -0.115072            0.141894
# prefill                              -0.099512            0.098332
# decode                               -0.252218            0.258147
# correct->correct                      1.000000           -0.976651
# correct->incorrect                   -0.976651            1.000000
# incorrect->correct                   -0.016122            0.115105
# incorrect->incorrect                 -0.022131           -0.079298
# mcNemar p value for accuracy               NaN                 NaN
# CI (95%)                                   NaN                 NaN
#
#                               incorrect->correct  incorrect->incorrect  \
# accuracy                                0.921781             -0.935528
# ppl                                     0.274062             -0.269553
# prefill                                -0.048364              0.090155
# decode                                  0.219953             -0.260521
# correct->correct                       -0.016122             -0.022131
# correct->incorrect                      0.115105             -0.079298
# incorrect->correct                      1.000000             -0.994698
# incorrect->incorrect                   -0.994698              1.000000
# mcNemar p value for accuracy                 NaN                   NaN
# CI (95%)                                     NaN                   NaN
#
#                               mcNemar p value for accuracy  CI (95%)
# accuracy                                               NaN       NaN
# ppl                                                    NaN       NaN
# prefill                                                NaN       NaN
# decode                                                 NaN       NaN
# correct->correct                                       NaN       NaN
# correct->incorrect                                     NaN       NaN
# incorrect->correct                                     NaN       NaN
# incorrect->incorrect                                   NaN       NaN
# mcNemar p value for accuracy                           NaN       NaN
# CI (95%)                                               NaN       NaN
