# %%
import benchmark_llm
benchllm=benchmark_llm.BenchLLM('../../llama.cpp/bin/llama-server','../../llama.cpp/bin/llama-perplexity','../../llama.cpp/smollm2-q4km.gguf')
benchllm.start_server()

# %%
benchllm.bench()
benchllm.save_to_file('name.json')
